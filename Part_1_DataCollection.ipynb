# %%
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
import numpy as np
from scipy.stats import norm
import seaborn as sns
import itertools

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/sna/df_top10.csv")
# Out:
# <ipython-input-81-5a141dfbd05b>:1: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/sna/df_top10.csv")

# %%
df.drop("Unnamed: 0",axis=1, inplace=True)

# %%
df
# Out:
#        Jurisdiction Kind         Display Key              Lens ID  \
# 0                PL   T3       PL 3366415 T3  004-922-905-812-852
# 1                JP    A       JP H1149729 A  005-125-037-091-331
# 2                US   A1  US 2014/0260277 A1  005-687-980-456-121
# 3                US   B2       US 9771874 B2  003-293-180-240-758
# 4                US   B2       US 9022730 B2  006-895-858-946-20X
# ...             ...  ...                 ...                  ...
# 352740           US   B2       US 8559504 B2  160-523-862-185-219
# 352741           CN    A      CN 105474589 A  165-886-896-198-856
# 352742           EP   B1       EP 3167642 B1  159-091-921-310-111
# 352743           JP    A     JP 2012010311 A  157-895-918-185-015
# 352744           JP    A     JP 2015029865 A  154-126-080-690-839
#
#        Publication Date  Publication Year Application Number Application Date  \
# 0            2023-03-06            2023.0      PL 18155149 T       2018-02-05
# 1            1999-02-23            1999.0      JP 11763998 A       1998-04-28
# 2            2014-09-18            2014.0  US 201313845485 A       2013-03-18
# 3            2017-09-26            2017.0  US 201414546512 A       2014-11-18
# 4            2015-05-05            2015.0      US 90101010 A       2010-10-08
# ...                 ...               ...                ...              ...
# 352740       2013-10-15            2013.0  US 201213706981 A       2012-12-06
# 352741       2016-04-06            2016.0  CN 201480044708 A       2014-07-02
# 352742       2020-03-11            2020.0      EP 15731130 A       2015-06-08
# 352743       2012-01-12            2012.0    JP 2011061549 A       2011-03-18
# 352744       2015-02-16            2015.0    JP 2013163781 A       2013-08-07
#
#                                                     Title    Applicants  \
# 0       METHOD OF BRAZING A TREATMENT AREA OF A LOAD-B...  GEN ELECTRIC
# 1       DIAMINOALKYL QUATERNARY AMMONIUM SALT AND ITS ...  GEN ELECTRIC
# 2       FLOW SLEEVE FOR A COMBUSTION MODULE OF A GAS T...  GEN ELECTRIC
# 3       Power output and fuel flow based probabilistic...  GEN ELECTRIC
# 4            Supersonic compressor startup support system  GEN ELECTRIC
# ...                                                   ...           ...
# 352740  Method and apparatus for coding image informat...     SONY CORP
# 352741                 Communications terminal and method     SONY CORP
# 352742  APPARATUS AND METHOD FOR PERFORMING SPECTRUM S...     SONY CORP
# 352743  TRANSMITTER, TRANSMISSION METHOD, RECEIVER, RE...     SONY CORP
# 352744  IMAGE PROCESSING APPARATUS AND METHOD, FUNDUS ...     SONY CORP
#
#                                                 Inventors  \
# 0       HENDERSON BRIAN LESLIE;;CUI YAN;;DORRIETY DANI...
# 1       BRUNELLE DANIEL JOSEPH;;PHELPS PETER DAVID;;BO...
# 2       DICINTIO RICHARD MARTIN;;MELTON PATRICK BENEDI...
# 3       DAVIS JR LEWIS BERKLEY;;DAY SCOTT ARTHUR;;JORD...
# 4                     VYSOHLID MARTIN;;HOFER DOUGLAS CARL
# ...                                                   ...
# 352740  SATO KAZUSHI;;SUNOHARA OSAMU;;SUZUKI TERUHIKO;...
# 352741           WAKABAYASHI HIDEJI;;WEBB MATTHEW WILLIAM
# 352742          FURUICHI SHO;;TSUDA SHINICHIRO;;SAWAI RYO
# 352743                                    TSUKAGOSHI IKUO
# 352744                                    KOBAYASHI SEIJI
#
#                                        Owners  \
# 0                                         NaN
# 1                                         NaN
# 2       GENERAL ELECTRIC COMPANY (2013-03-15)
# 3       GENERAL ELECTRIC COMPANY (2014-11-04)
# 4       GENERAL ELECTRIC COMPANY (2010-10-06)
# ...                                       ...
# 352740                                    NaN
# 352741                                    NaN
# 352742                                    NaN
# 352743                                    NaN
# 352744                                    NaN
#
#                                       CPC Classifications  \
# 0       B23K1/0018;;B23K1/19;;B23P6/002;;B23P6/007;;F0...
# 1       C07D295/13;;C07D295/13;;C07C211/63;;C07C211/63...
# 2       F23R3/005;;F23R3/46;;F23R3/60;;F23R2900/00017;...
# 3       F02C9/28;;F02C9/28;;F02C3/04;;F02C3/04;;F05D22...
# 4              F04D21/00;;F04D21/00;;F04D27/02;;F04D27/02
# ...                                                   ...
# 352740  H04N19/61;;H04N19/60;;H04N19/126;;H04N19/186;;...
# 352741  H04L47/2416;;H04L47/30;;H04W28/0231;;H04W52/02...
# 352742  H04W16/14;;H04W64/003;;H04W16/14;;H04W64/003;;...
# 352743  H04N13/183;;H04N13/183;;H04N7/24;;H04N7/24;;H0...
# 352744  A61B3/0025;;A61B3/0025;;A61B3/12;;A61B3/12;;A6...
#
#                                      IPCR Classifications Legal Status  \
# 0       B23P6/00;;B23K1/00;;B23K1/002;;B23K1/19;;B23P6...      PENDING
# 1       C07D295/02;;B01J31/02;;C07B61/00;;C07C68/02;;C...      EXPIRED
# 2                                                F23R3/20       ACTIVE
# 3                                      F02C9/28;;F02C3/04       ACTIVE
# 4                                    F04D21/00;;F04D27/02       ACTIVE
# ...                                                   ...          ...
# 352740             H04B1/66;;G06T9/00;;H04N7/26;;H04N7/50      EXPIRED
# 352741                  H04L47/2416;;H04L47/30;;H04L47/32       ACTIVE
# 352742                    H04W16/14;;H04W4/021;;H04W64/00       ACTIVE
# 352743        H04N7/173;;G10L19/00;;H04N13/00;;H04N21/442      PENDING
# 352744                                           A61B3/14       ACTIVE
#
#         num_inventors Abstract
# 0                 5.0      NaN
# 1                 7.0      NaN
# 2                 5.0      NaN
# 3                 4.0      NaN
# 4                 2.0      NaN
# ...               ...      ...
# 352740            NaN      NaN
# 352741            NaN      NaN
# 352742            NaN      NaN
# 352743            NaN      NaN
# 352744            NaN      NaN
#
# [352745 rows x 17 columns]

# %%
def generate_inventor_pairs(inventor_list):
    pairs = list(itertools.combinations(inventor_list, 2))
    return pairs

# %%
# Creazione coppie inventori per costruire il grafo bipartito
pair_counts = {}

for index, row in df.iterrows():
    inventors = row['Inventors']

    if pd.isna(inventors) or not isinstance(inventors, str):
        continue

    inventors = inventors.split(';;')
    pairs = generate_inventor_pairs(inventors)

    for pair in pairs:
        if pair in pair_counts:
            pair_counts[pair] += 1
        else:
            pair_counts[pair] = 1


new_rows = []

for pair, count in pair_counts.items():
    source, target = pair
    new_rows.append({'Source': source, 'Target': target, 'Weight': count})

new_df = pd.DataFrame(new_rows)

# %%
df_plot=new_df

# %%
new_df.sort_values('Weight',ascending=False)
# Out:
#                 Source              Target  Weight
# 235815   CHENG KANGGUO     KHAKIFIROOZ ALI    1111
# 345424   ALSHINA ELENA    ALSHIN ALEXANDER     784
# 346715  HWANG SUNG-HEE         KO JUNG-WAN     782
# 345662       LEE TAMMY         HAN WOO-JIN     771
# 235817   CHENG KANGGUO  REZNICEK ALEXANDER     758
# ...                ...                 ...     ...
# 222400   HOTTA TAKASHI   KURITA KIMISABURO       1
# 222401   HOTTA TAKASHI      AGANO MASAHIRO       1
# 222402      MASUDA KAO    IWAMURA MASAHIRO       1
# 222403      MASUDA KAO   KURITA KIMISABURO       1
# 411080        OTA KOJI     KOBAYASHI NAOKI       1
#
# [411081 rows x 3 columns]

# %%
colonna_da_confrontare = "Weight"
new_df = new_df[new_df[colonna_da_confrontare] >= 12]

# %%
new_df
# Out:
#                         Source                 Target  Weight
# 0       HENDERSON BRIAN LESLIE                CUI YAN      28
# 1       HENDERSON BRIAN LESLIE  DORRIETY DANIEL JAMES      28
# 2       HENDERSON BRIAN LESLIE   SHUBERT GARY CHARLES      12
# 3       HENDERSON BRIAN LESLIE       COOK PAUL ALBERT      28
# 4                      CUI YAN  DORRIETY DANIEL JAMES      54
# ...                        ...                    ...     ...
# 400927            INOUE HAJIME           SHIMA HISATO      14
# 400939       MATSUMOTO ATSUSHI    NISHIGUCHI MASAYUKI      17
# 402379         TSUBOI HISANORI       UCHINO KATSUHIDE      12
# 402476      NAKAMURA TAKATOSHI       SAKATA JUNICHIRO      12
# 403446    FUNAWATARI TAKATSUGU        KIKUCHI SHUICHI      12
#
# [55847 rows x 3 columns]

# %%
new_df.sort_values('Weight',ascending=False)
# Out:
#                       Source              Target  Weight
# 235815         CHENG KANGGUO     KHAKIFIROOZ ALI    1111
# 345424         ALSHINA ELENA    ALSHIN ALEXANDER     784
# 346715        HWANG SUNG-HEE         KO JUNG-WAN     782
# 345662             LEE TAMMY         HAN WOO-JIN     771
# 235817         CHENG KANGGUO  REZNICEK ALEXANDER     758
# ...                      ...                 ...     ...
# 56247           TANI ATSUSHI        YANO TETSUYA      12
# 351850          KIM YONG-TAE       KIM JAE-SEUNG      12
# 351841       HWANG SEO-YOUNG       KIM JAE-SEUNG      12
# 351837          CHO SONGYEAN        JANG JAEHYUK      12
# 403446  FUNAWATARI TAKATSUGU     KIKUCHI SHUICHI      12
#
# [55847 rows x 3 columns]

# %%
conteggio = new_df['Source'].value_counts()

print(conteggio)
# Out:
# SAKO YOICHIRO             129
# CHENG KANGGUO             115
# KONDO TETSUJIRO           109
# BEWLAY BERNARD PATRICK    106
# KUMAR AJITH KUTTANNAIR     98
#                          ...
# MURATA SHINJI               1
# YURA MASASHI                1
# SHIMA YOSHIHIRO             1
# KURAHASHI AKIRA             1
# TSUBOI HISANORI             1
# Name: Source, Length: 10596, dtype: int64

# %%
conteggio = new_df['Weight'].value_counts()
print(conteggio)
# Out:
# 12     6718
# 14     4842
# 16     3528
# 13     3414
# 18     2706
#        ...
# 357       1
# 486       1
# 448       1
# 367       1
# 312       1
# Name: Weight, Length: 417, dtype: int64

# %%
def plot_graph(G):
    nx.draw(G, with_labels=True)
    plt.show()

# %%
G_test=nx.Graph()
for _, row in new_df.iterrows():
    source = row['Source']
    target = row['Target']
    weight = row['Weight']


    G_test.add_node(source)
    G_test.add_node(target)

    G_test.add_edge(source, target, weight=weight)

# %%
print("Number of Nodes: ", G_test.order()) # equivalent to len(G) and G.number_of_nodes()
print("Number of Edges: ", G_test.number_of_edges())
# Out:
# Number of Nodes:  13619
# Number of Edges:  46487

# %%
df_plot.describe().T
# Out:
#            count      mean        std  min  25%  50%  75%     max
# Weight  411081.0  6.958595  17.364898  1.0  1.0  2.0  6.0  1111.0

# %%
#Per selezionare le relazioni più significative impostiamo una soglia in base alla distribuzione dei pesi

# %%
weight= df_plot['Weight'].values

# %%
media = np.mean(weight)
deviazione_standard = np.std(weight)
x = np.linspace(media - 3 * deviazione_standard, media + 3 * deviazione_standard, 100)
y = norm.pdf(x, media, deviazione_standard)

plt.hist(weight, bins=50, density=True, alpha=0.5, range=(15, 200), label='Distribuzione dei valori')
plt.ylim(0, 0.025)

plt.plot(x, y, 'r', label='Distribuzione normale')

plt.xlabel('Valore')
plt.ylabel('Densità')
plt.title('Distribuzione dei valori della colonna (con distribuzione normale)')
plt.legend()
plt.show()

# %%
df_plot
# Out:
#                                 Source                 Target  Weight
# 0               HENDERSON BRIAN LESLIE                CUI YAN      28
# 1               HENDERSON BRIAN LESLIE  DORRIETY DANIEL JAMES      28
# 2               HENDERSON BRIAN LESLIE   SHUBERT GARY CHARLES      12
# 3               HENDERSON BRIAN LESLIE       COOK PAUL ALBERT      28
# 4                              CUI YAN  DORRIETY DANIEL JAMES      54
# ...                                ...                    ...     ...
# 411076  HEEMSKERK JACOBUS PETRUS JOSEP             ABE SHINYA       1
# 411077                    FURUICHI SHO          KURIKI HIROTO       1
# 411078                   KURIKI HIROTO       TSUDA SHINICHIRO       1
# 411079                    TANAKA KENJI          TAKECHI HIDEO       1
# 411080                        OTA KOJI        KOBAYASHI NAOKI       1
#
# [411081 rows x 3 columns]
